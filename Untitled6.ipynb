# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\TUSHAR\OneDrive\Desktop\test jupyter\Book123.xlsx")
df.head()
# Out:
#    mileage  age(yrs)  sell price(us$)
# 0    69000         6            18000
# 1    35000         3            34000
# 2    57000         5            26100
# 3    22500         2            40000
# 4    46000         4            31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['mileage'],df['sell price(us$)'])

# %%
plt.scatter(df['age(yrs)'],df['sell price(us$)'])

# %%
x=df[['mileage','age(yrs)']]

# %%
y=df['sell price(us$)']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
x_train
# Out:
#    mileage  age(yrs)
# 6    52000         5
# 3    22500         2
# 1    35000         3
# 0    69000         6
# 7    72000         6
# 4    46000         4
# 9    67000         6

# %%
len(x_test)
# Out:
# 3

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([12000., 26100., 26750.])

# %%
y_test
# Out:
# 8    12000
# 2    26100
# 5    26750
# Name: sell price(us$), dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 1.0
